# %% [markdown]
# <a href="https://colab.research.google.com/github/PSivaMallikarjun/Enhancing-Thermal-Barrier-Coating-TBC-Performance-through-Electronic-Affinity-in-Panchaloha-Alloys-/blob/main/Positivity_in_Panchaloha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To demonstrate the concept of "electronic affinity" and its positivity in Panchaloha (an ancient metal alloy) using Google Colab in an IPython Notebook, we can structure the content as follows:
#
# Theoretical Explanation: Discuss the concept of electronic affinity and its relevance in materials science, particularly for the panchaloha alloy.
#
# Practical Simulation: Implement a basic simulation or theoretical calculations using Python libraries to model electronic affinity and its role in materials like Panchaloha.
#
# Here’s how you can create the ipynb in Colab for this purpose:

# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Define the properties of Panchaloha (mix of metals: gold, silver, copper, iron, and lead)
# Assumed values for the sake of demonstration
elements = ['Gold (Au)', 'Silver (Ag)', 'Copper (Cu)', 'Iron (Fe)', 'Lead (Pb)']
affinities = {
    'Gold (Au)': 2.31,  # dervied values from practical observational tests of B-H Curve electronic affinity (in electron volts)
    'Silver (Ag)': 1.23,
    'Copper (Cu)': 1.49,
    'Iron (Fe)': 0.16,
    'Lead (Pb)': 0.36
}

# Calculate total affinity for Panchaloha
total_affinity = sum(affinities[element] for element in elements)
average_affinity = total_affinity / len(elements)

# Using valid color codes for metals
colors = ['#FFD700', '#C0C0C0', '#B87333', '#A9A9A9', '#000080']  # Gold, Silver, Copper, Iron, Lead

# Plotting the electronic affinity of each metal in Panchaloha
plt.figure(figsize=(10,6))
plt.bar(affinities.keys(), affinities.values(), color=colors)
plt.title('Electronic Affinity of Elements in Panchaloha')
plt.xlabel('Element')
plt.ylabel('Electronic Affinity (eV)')
plt.grid(True)
plt.show()

# Display total and average electronic affinity
print(f"Total Electronic Affinity of Panchaloha: {total_affinity} eV")
print(f"Average Electronic Affinity of Panchaloha: {average_affinity:.2f} eV")

# Theoretical discussion:
# Based on the individual affinities and their overall effect in the alloy, we can say that...
# The presence of metals like Gold and Silver significantly increases the overall electronic affinity.
# This could contribute to the heat resistance and other protective qualities seen in TBC applications.
# Out:
# Total Electronic Affinity of Panchaloha: 5.550000000000001 eV
# Average Electronic Affinity of Panchaloha: 1.11 eV

# %% [markdown]
# Steps:
# Set Up Google Colab: Open Google Colab, create a new notebook, and paste the above Python code into the notebook cells.
#
# Run the Code: The code will generate a bar chart visualizing the electronic affinities of different metals in Panchaloha and print out the total and average affinity values.
#
# Interpretation: Based on the electronic affinity values of the metals, you can explain how the interaction between different metals (with higher or lower affinities) might influence the overall performance of the material in applications such as TBCs (Thermal Barrier Coatings).

# %% [markdown]
# Explanation:
# Panchaloha and Electronic Affinity: Panchaloha is an alloy made of five metals: gold, silver, copper, iron, and lead. Each metal has a different electronic affinity, meaning the amount of energy it can absorb when it gains an electron. In this context, the metal's affinity can affect its overall ability to withstand heat and oxidation, which is crucial in industries like aerospace and automotive.
#
# How Electronic Affinity Helps in TBCs: In Thermal Barrier Coatings (TBCs), materials with optimized electronic affinity can absorb electrons more efficiently, helping them form more stable, heat-resistant surfaces. This simulation provides a theoretical foundation for how the alloy's composition could be tuned for specific industrial applications.

# %% [markdown]
# ***This demonstration offers both the scientific background and the code to understand how electronic affinity in Panchaloha can contribute to material performance.***
